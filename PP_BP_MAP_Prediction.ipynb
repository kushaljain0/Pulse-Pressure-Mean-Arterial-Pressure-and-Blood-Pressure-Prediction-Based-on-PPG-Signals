# %% [markdown]
# ### Importing all the libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as pypl

# %% [markdown]
# ### Importing PPG Dataset

# %%
data = pd.read_csv("PPG_DATA.csv")
data.head()
# Out:
#       WAVEFORM1  WAVEFORM2  WAVEFORM3  WAVEFORM4  WAVEFORM5  WAVEFORM6  \
# 0  7.120000e-20   0.006322   0.016137   0.025607   0.034752   0.044423
# 1  7.680000e-20   0.006777   0.017221   0.027176   0.036762   0.046977
# 2 -2.440000e-20   0.001356   0.003986   0.007110   0.010962   0.015314
# 3 -3.920000e-20   0.000983   0.003167   0.005999   0.009796   0.014178
# 4  7.990000e-20   0.006781   0.017248   0.027266   0.036839   0.046923
#
#    WAVEFORM7  WAVEFORM8  WAVEFORM9  WAVEFORM10  ...      S3       S4  \
# 0   0.055659   0.066833   0.078345    0.089979  ...  14.001  0.33133
# 1   0.058772   0.070409   0.082392    0.094594  ...  15.807  0.45207
# 2   0.020616   0.026297   0.032708    0.039446  ...  11.526  0.14466
# 3   0.019597   0.025503   0.032318    0.039556  ...  12.626  0.14622
# 4   0.058624   0.070215   0.082109    0.094108  ...  15.373  0.33431
#
#    RATIO_B_A  RATIO_E_A    DLASI1    DLASI2     MAP    SBP    DBP     PP
# ...

# %% [markdown]
# ### Details about Data

# %%
print(data.shape)
print(data.columns)
# Out:
# (145827, 146)
# Index(['WAVEFORM1', 'WAVEFORM2', 'WAVEFORM3', 'WAVEFORM4', 'WAVEFORM5',
#        'WAVEFORM6', 'WAVEFORM7', 'WAVEFORM8', 'WAVEFORM9', 'WAVEFORM10',
#        ...
#        'S3', 'S4', 'RATIO_B_A', 'RATIO_E_A', 'DLASI1', 'DLASI2', 'MAP', 'SBP',
#        'DBP', 'PP'],
#       dtype='object', length=146)

# %% [markdown]
# ### Getting Insights On the Data at different intervals

# %%
sampleData1 = data.iloc[1][:"WAVEFORM125"]
#print(sampleData1,end= " \n\n")

sampleData2 = data.iloc[10][:"WAVEFORM125"]
#print(sampleData2,end= " \n\n")

sampleData3 = data.iloc[100][:"WAVEFORM125"]
#print(sampleData3,end= " \n\n")

sampleData4 = data.iloc[1000][:"WAVEFORM125"]
#print(sampleData4,end= " \n\n")

sampleData5 = data.iloc[10000][:"WAVEFORM125"]
#print(sampleData5,end= " \n\n")

sampleData6 = data.iloc[100000][:"WAVEFORM125"]
#print(sampleData6,end= " \n\n")

# %%
columns = list(range(0,len(sampleData1)))

# %%
y = sampleData1
pypl.plot(columns,y)

# %%
y = sampleData2
pypl.plot(columns,y)

# %%
y = sampleData3
pypl.plot(columns,y)

# %%
y = sampleData4
pypl.plot(columns,y)

# %%
y = sampleData5
pypl.plot(columns,y)

# %% [markdown]
# #### We see that the signal is not varying much, so to get an insight on variation of signals we plot the variation of all entries with target value Pulse Pressure and Mean Arterial Pressure

# %% [markdown]
# #### Pulse Pressure

# %%
PPdata = data["PP"]
rows = [range(0, len(PPdata))]
f = pypl.figure()
f.set_figwidth(30)
f.set_figheight(30)
pypl.scatter(rows,PPdata)

# %% [markdown]
# #### Muscle Arterial Pressure

# %%
MAPdata = data["MAP"]
rows = list(range(0, len(MAPdata)))
f = pypl.figure()
f.set_figwidth(30)
f.set_figheight(30)
pypl.scatter(rows,MAPdata)

# %% [markdown]
# #### Analyzing the ranges of data from above plots

# %%
sampleData1 = data.iloc[1][:"WAVEFORM125"]
#print(sampleData1,end= " \n\n")

sampleData2 = data.iloc[28000][:"WAVEFORM125"]
#print(sampleData2,end= " \n\n")

sampleData3 = data.iloc[50000][:"WAVEFORM125"]
#print(sampleData3,end= " \n\n")

sampleData4 = data.iloc[70000][:"WAVEFORM125"]
#print(sampleData4,end= " \n\n")

sampleData5 = data.iloc[90000][:"WAVEFORM125"]
#print(sampleData5,end= " \n\n")

sampleData6 = data.iloc[100000][:"WAVEFORM125"]
#print(sampleData6,end= " \n\n")

sampleData7 = data.iloc[110000][:"WAVEFORM125"]
#print(sampleData7,end= " \n\n")

sampleData8 = data.iloc[120000][:"WAVEFORM125"]
#print(sampleData8,end= " \n\n")

sampleData9 = data.iloc[130000][:"WAVEFORM125"]
#print(sampleData9,end= " \n\n")

sampleData10 = data.iloc[140000][:"WAVEFORM125"]
#print(sampleData10,end= " \n\n")

# %%
pypl.plot(columns,sampleData1)

# %%
pypl.plot(columns,sampleData2)

# %%
pypl.plot(columns,sampleData3)

# %%
pypl.plot(columns,sampleData4)

# %%
pypl.plot(columns,sampleData5)

# %%
pypl.plot(columns,sampleData6)

# %%
pypl.plot(columns,sampleData7)

# %%
pypl.plot(columns,sampleData8)

# %%
pypl.plot(columns,sampleData9)

# %%
pypl.plot(columns,sampleData10)

# %% [markdown]
# #### We can see that according to the ranges of target values, the signals are changing significantly.
# #### Now lets see how different features change with different signals.

# %%
features = ["NOTCH_DISTANCE","PEAK_DISTANCE1","PEAK_DISTANCE2","DIFFRENTIATED_PEAK","CREST","DICROTIC","AMPLITUDE","AUG_INDEX","LASI","S1","S2","S3","S4","RATIO_B_A","RATIO_E_A","DLASI1","DLASI2"]
print(len(features))
y = data[features[0]]
pypl.plot(rows, y)
# Out:
# 17

# %%
y = data[features[1]]
pypl.plot(rows, y)

# %%
y = data[features[2]]
pypl.plot(rows, y)

# %%
y = data[features[3]]
pypl.plot(rows, y)

# %%
y = data[features[4]]
pypl.plot(rows, y)

# %%
y = data[features[5]]
pypl.plot(rows, y)

# %%
y = data[features[6]]
pypl.plot(rows, y)

# %%
y = data[features[7]]
pypl.plot(rows, y)

# %%
y = data[features[8]]
pypl.plot(rows, y)

# %%
y = data[features[9]]
pypl.plot(rows, y)

# %%
y = data[features[10]]
pypl.plot(rows, y)

# %%
y = data[features[11]]
pypl.plot(rows, y)

# %%
y = data[features[12]]
pypl.plot(rows, y)

# %%
y = data[features[13]]
pypl.plot(rows, y)

# %%
y = data[features[14]]
pypl.plot(rows, y)

# %%
y = data[features[15]]
pypl.plot(rows, y)

# %%
y = data[features[16]]
pypl.plot(rows, y)

# %% [markdown]
# #### From the above plots we can see that there are some features which do not change significantly, these features do not contribute anything to the model therefore they can be discarded.
#
# #### Now, lets compare the features with target values based on above plots.

# %% [markdown]
# ### Feature Vs Pulse Pressure

# %%
f = pypl.figure()
f.set_figwidth(20)
f.set_figheight(20)
pypl.scatter(data[features[0]],PPdata)

# %%
f = pypl.figure()
f.set_figwidth(20)
f.set_figheight(20)
pypl.scatter(data[features[2]],PPdata)

# %%
f = pypl.figure()
f.set_figwidth(20)
f.set_figheight(20)
pypl.scatter(data[features[7]],PPdata)

# %%
f = pypl.figure()
f.set_figwidth(20)
f.set_figheight(20)
pypl.scatter(data[features[8]],PPdata)

# %%
f = pypl.figure()
f.set_figwidth(20)
f.set_figheight(20)
pypl.scatter(data[features[9]],PPdata)

# %%
f = pypl.figure()
f.set_figwidth(20)
f.set_figheight(20)
pypl.scatter(data[features[13]],PPdata)

# %%
f = pypl.figure()
f.set_figwidth(20)
f.set_figheight(20)
pypl.scatter(data[features[14]],PPdata)

# %%
f = pypl.figure()
f.set_figwidth(20)
f.set_figheight(20)
pypl.scatter(data[features[16]],PPdata)

# %% [markdown]
# ### Feature vs Mean Arterial Pressure

# %%
f = pypl.figure()
f.set_figwidth(20)
f.set_figheight(20)
pypl.scatter(data[features[0]],MAPdata)

# %%
f = pypl.figure()
f.set_figwidth(20)
f.set_figheight(20)
pypl.scatter(data[features[2]],MAPdata)

# %%
f = pypl.figure()
f.set_figwidth(20)
f.set_figheight(20)
pypl.scatter(data[features[7]],MAPdata)

# %%
f = pypl.figure()
f.set_figwidth(20)
f.set_figheight(20)
pypl.scatter(data[features[8]],MAPdata)

# %%
f = pypl.figure()
f.set_figwidth(20)
f.set_figheight(20)
pypl.scatter(data[features[9]],MAPdata)

# %%
f = pypl.figure()
f.set_figwidth(20)
f.set_figheight(20)
pypl.scatter(data[features[13]],MAPdata)

# %%
f = pypl.figure()
f.set_figwidth(20)
f.set_figheight(20)
pypl.scatter(data[features[14]],MAPdata)

# %%
f = pypl.figure()
f.set_figwidth(20)
f.set_figheight(20)
pypl.scatter(data[features[16]],MAPdata)

# %% [markdown]
# #### Now let us apply some different feature selection methods

# %% [markdown]
# #### (1) Correlation Matrix

# %%
dict_features = {}
features_and_target = ["NOTCH_DISTANCE","PEAK_DISTANCE1","PEAK_DISTANCE2","DIFFRENTIATED_PEAK","CREST","DICROTIC","AMPLITUDE","AUG_INDEX","LASI","S1","S2","S3","S4","RATIO_B_A","RATIO_E_A","DLASI1","DLASI2", "PP", "MAP"]
for i in range(0,19):
    dict_features[features_and_target[i]] = data[features_and_target[i]]

corre = pd.DataFrame(dict_features)
corrmatrix = corre.corr()
corrmatrix
# Out:
#                     NOTCH_DISTANCE  PEAK_DISTANCE1  PEAK_DISTANCE2  \
# NOTCH_DISTANCE            1.000000        0.836483        0.973533
# PEAK_DISTANCE1            0.836483        1.000000        0.809968
# PEAK_DISTANCE2            0.973533        0.809968        1.000000
# DIFFRENTIATED_PEAK       -0.000538       -0.013672       -0.012215
# CREST                     0.337439        0.278637        0.303785
# DICROTIC                  0.315068        0.312037        0.252071
# AMPLITUDE                 0.117795        0.147986        0.102977
# AUG_INDEX                 0.509292        0.465573        0.506548
# LASI                     -0.218058       -0.204819       -0.203951
# S1                       -0.204454       -0.203735       -0.211019
# S2                        0.499277        0.474645        0.441205
# S3                        0.533291        0.544147        0.482609
# S4                        0.557949        0.366686        0.550454
# ...

# %%
sns.set(rc = {'figure.figsize':(16,10)})
sns.heatmap(corrmatrix, 
        xticklabels=corrmatrix.columns,
        yticklabels=corrmatrix.columns, annot = True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### Selected Features from above correlation matrix for each target value and converting in standard format to train the Model

# %%
PP_Selected_Features = [features[1], features[2], features[5], features[7],  features[12], features[14], features[15], features[16]]
MAP_Selected_Features = [features[2], features[7], features[11], features[12], features[14], features[16]]
selectedF = []
for i in range (0, len(PP_Selected_Features)):
    selectedF.append(data[PP_Selected_Features[i]])
selectedF = np.transpose(selectedF)

PPdata = data["PP"]
MAPdata = data["MAP"]
SBPdata = data["SBP"]
DBPdata = data["DBP"]
PPdata = list(PPdata)
MAPdata = list(MAPdata)
SBPdata = list(SBPdata)
DBPdata = list(DBPdata)
def extractDigits(lst):
    return list(map(lambda el:[el], lst))

PPdata = extractDigits(PPdata)
MAPdata = extractDigits(MAPdata)
SBPdata = extractDigits(SBPdata)
DBPdata = extractDigits(DBPdata)
print(f"Selected Features for PP : ", PP_Selected_Features)
print(f"Selected Features for MAP : ", MAP_Selected_Features)
# Out:
# Selected Features for PP :  ['PEAK_DISTANCE1', 'PEAK_DISTANCE2', 'DICROTIC', 'AUG_INDEX', 'S4', 'RATIO_E_A', 'DLASI1', 'DLASI2']
# Selected Features for MAP :  ['PEAK_DISTANCE2', 'AUG_INDEX', 'S3', 'S4', 'RATIO_E_A', 'DLASI2']

# %% [markdown]
# #### Test-Train Splitting of Data for PP

# %%
import random
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(selectedF, PPdata, test_size=0.3, random_state=42,shuffle=True)

# %% [markdown]
# #### Training Model on Decision Tree Regressor for PP

# %%
from sklearn import tree
model = tree.DecisionTreeRegressor()
model = model.fit(X_train, y_train)
y_pred= model.predict(X_test)

# %% [markdown]
# #### R^2, MAE and MSE for PP

# %%
from sklearn.metrics import r2_score
print(f"R^2 value : ", r2_score(y_test, y_pred))

from sklearn.metrics import mean_absolute_error
print(f"MAE value : ", mean_absolute_error(y_test, y_pred))

from sklearn.metrics import mean_squared_error
print(f"MSE value : ", mean_squared_error(y_test, y_pred))
# Out:
# R^2 value :  0.9793016370682454
# MAE value :  0.459796482477424
# MSE value :  4.062961899741705

# %% [markdown]
# #### Test-Train Splitting of Data for MAP

# %%
import random
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(selectedF, MAPdata, test_size=0.3, random_state=42,shuffle=True)

# %% [markdown]
# #### Training Model on Decision Tree Regressor for MAP

# %%
from sklearn import tree
model = tree.DecisionTreeRegressor()
model = model.fit(X_train, y_train)
y_pred= model.predict(X_test)

# %% [markdown]
# #### R^2, MAE and MSE for MAP

# %%
from sklearn.metrics import r2_score
print(f"R^2 value : ", r2_score(y_test, y_pred))

from sklearn.metrics import mean_absolute_error
print(f"MAE value : ", mean_absolute_error(y_test, y_pred))

from sklearn.metrics import mean_squared_error
print(f"MSE value : ", mean_squared_error(y_test, y_pred))
# Out:
# R^2 value :  0.9820583586993046
# MAE value :  0.38886190737421017
# MSE value :  2.434536016836064

# %% [markdown]
# #### K-fold Cross Validation for Decision Tree Model

# %%
# from sklearn import tree
# model = tree.DecisionTreeRegressor()
# # model = model.fit(X_train, y_train)
# # y_pred= model.predict(X_test)

# from sklearn.model_selection import cross_val_score, RepeatedKFold
# cv = RepeatedKFold(n_splits=20, n_repeats=10, random_state=1)
# # evaluate model
# scores = cross_val_score(model, selectedF, PPdata, scoring='r2', cv=cv, n_jobs=-1)
# print(scores)
# print(scores.mean())
# print(scores.std())

# %%
# from sklearn import tree
# model = tree.DecisionTreeRegressor()
# # model = model.fit(X_train, y_train)
# # y_pred= model.predict(X_test)

# from sklearn.model_selection import cross_val_score, RepeatedKFold
# cv = RepeatedKFold(n_splits=20, n_repeats=10, random_state=1)
# # evaluate model
# scores = cross_val_score(model, selectedF, MAPdata, scoring='r2', cv=cv, n_jobs=-1)
# print(scores)
# print(scores.mean())
# print(scores.std())

# %% [markdown]
# #### Test-Train Splitting of Data for PP

# %%
import random
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(selectedF, PPdata, test_size=0.3, random_state=42,shuffle=True)

# %% [markdown]
# #### Training Model on Random Forest Regressor for PP

# %%
from sklearn import ensemble
model = ensemble.RandomForestRegressor()
model = model.fit(X_train, y_train)
y_pred= model.predict(X_test)
# Out:
# C:\Users\asus\AppData\Local\Temp\ipykernel_5596\3060015572.py:3: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   model = model.fit(X_train, y_train)

# %% [markdown]
# #### R^2, MAE and MSE for PP

# %%
from sklearn.metrics import r2_score
print(f"R^2 value : ", r2_score(y_test, y_pred))

from sklearn.metrics import mean_absolute_error
print(f"MAE value : ", mean_absolute_error(y_test, y_pred))

from sklearn.metrics import mean_squared_error
print(f"MSE value : ", mean_squared_error(y_test, y_pred))
# Out:
# R^2 value :  0.9890030761138633
# MAE value :  0.47839130731090845
# MSE value :  2.158628820600411

# %%
def best_fit(testY, testPredict):

    sty = 0
    for i in testY:
        sty += i[0]
    spre = 0
    for i in testPredict:
        spre += i
        
    
    xbar = sty/len(testY)
    ybar = spre/len(testPredict)
    n = len(testY) # or len(Y)

    numer = sum([xi[0]*yi for xi,yi in zip(testY, testPredict)]) - n * xbar * ybar
    denum = sum([xi[0]**2 for xi in testY]) - n * xbar**2

    b = numer / denum
    a = ybar - b * xbar

    # print('best fit line:\ny = {:.2f} + {:.2f}x'.format(a, b))

    return a, b

a, b = best_fit(y_test, y_pred)
#best fit line:
#y = 0.80 + 0.92x

# plot points and fit line
import matplotlib.pyplot as plt
plt.scatter(y_test, y_pred,color='Red')
yfit = [a + b * xi[0] for xi in y_test]
plt.plot(y_test, yfit,color ='black')
plt.xlabel("Target(mmHg)",fontsize=18)
plt.ylabel("PP Estimation(mmHg)",fontsize=18)
plt.legend(['R=0.989', f'Best fit Line y = {a} + x*{b}'],fontsize=18)
plt.savefig('PPscatter.jpg', format='jpg', dpi=1200)

# %% [markdown]
# #### Test-Train Splitting of Data for MAP

# %%
import random
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(selectedF, MAPdata, test_size=0.3, random_state=42,shuffle=True)

# %% [markdown]
# #### Training on Random Forest Regressor for MAP

# %%
from sklearn import ensemble
model = ensemble.RandomForestRegressor()
model = model.fit(X_train, y_train)
y_pred= model.predict(X_test)
# Out:
# C:\Users\asus\AppData\Local\Temp\ipykernel_5596\3060015572.py:3: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   model = model.fit(X_train, y_train)

# %% [markdown]
# #### R^2, MAE and MSE for MAP

# %%
from sklearn.metrics import r2_score
print(f"R^2 value : ", r2_score(y_test, y_pred))

from sklearn.metrics import mean_absolute_error
print(f"MAE value : ", mean_absolute_error(y_test, y_pred))

from sklearn.metrics import mean_squared_error
print(f"MSE value : ", mean_squared_error(y_test, y_pred))
# Out:
# R^2 value :  0.991668621799316
# MAE value :  0.3969666362375199
# MSE value :  1.1305008253989488

# %%
def best_fit(testY, testPredict):

    sty = 0
    for i in testY:
        sty += i[0]
    spre = 0
    for i in testPredict:
        spre += i
        
    
    xbar = sty/len(testY)
    ybar = spre/len(testPredict)
    n = len(testY) # or len(Y)

    numer = sum([xi[0]*yi for xi,yi in zip(testY, testPredict)]) - n * xbar * ybar
    denum = sum([xi[0]**2 for xi in testY]) - n * xbar**2

    b = numer / denum
    a = ybar - b * xbar

    # print('best fit line:\ny = {:.2f} + {:.2f}x'.format(a, b))

    return a, b

a, b = best_fit(y_test, y_pred)
#best fit line:
#y = 0.80 + 0.92x

# plot points and fit line
import matplotlib.pyplot as plt
plt.scatter(y_test, y_pred,color='Red')
yfit = [a + b * xi[0] for xi in y_test]
plt.plot(y_test, yfit,color ='black')
plt.xlabel("Target(mmHg)",fontsize=18)
plt.ylabel("MAP Estimation(mmHg)",fontsize=18)
plt.legend(['R^2=0.9915', f'y = {a} + x*{b}'],fontsize=18)
plt.savefig('reg.jpg', format='jpg', dpi=1200)

# %% [markdown]
# #### (2) Principal Component Analysis

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components = 8)
pca_features = pca.fit_transform(data[features_and_target[0: 17]])
pca_features = pd.DataFrame(data = pca_features, columns = [f"PC {i + 1}" for i in range(8)])
new_features = [f"PC {i + 1}" for i in range(8)]
pca_features

# %% [markdown]
# #### Test-Train Splitting of Data for PP

# %%
import random
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(pca_features, PPdata, test_size=0.3, random_state=42,shuffle=True)

# %% [markdown]
# #### Training on Decision Tree Regressor for PP

# %%
from sklearn import tree
model = tree.DecisionTreeRegressor()
model = model.fit(X_train, y_train)
y_pred= model.predict(X_test)

# %% [markdown]
# #### R^2, MAE and MSE for PP

# %%
from sklearn.metrics import r2_score
print(f"R^2 value : ", r2_score(y_test, y_pred))

from sklearn.metrics import mean_absolute_error
print(f"MAE value : ", mean_absolute_error(y_test, y_pred))

from sklearn.metrics import mean_squared_error
print(f"MSE value : ", mean_squared_error(y_test, y_pred))

# %% [markdown]
# #### Test-Train Splitting of Data for MAP

# %%
import random
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(pca_features, MAPdata, test_size=0.3, random_state=42,shuffle=True)

# %% [markdown]
# #### Training on Decision Tree Regressor for MAP

# %%
from sklearn import tree
model = tree.DecisionTreeRegressor()
model = model.fit(X_train, y_train)
y_pred= model.predict(X_test)

# %% [markdown]
# #### R^2, MAE and MSE for MAP

# %%
from sklearn.metrics import r2_score
print(f"R^2 value : ", r2_score(y_test, y_pred))

from sklearn.metrics import mean_absolute_error
print(f"MAE value : ", mean_absolute_error(y_test, y_pred))

from sklearn.metrics import mean_squared_error
print(f"MSE value : ", mean_squared_error(y_test, y_pred))

# %% [markdown]
# #### Test-Train Splitting of Data for PP

# %%
import random
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(pca_features, PPdata, test_size=0.3, random_state=42,shuffle=True)

# %% [markdown]
# #### Training on Random Forest Regressor for PP

# %%
from sklearn import ensemble
model = ensemble.RandomForestRegressor()
model = model.fit(X_train, y_train)
y_pred= model.predict(X_test)

# %% [markdown]
# #### R^2, MAE and MSE for PP

# %%
from sklearn.metrics import r2_score
print(f"R^2 value : ", r2_score(y_test, y_pred))

from sklearn.metrics import mean_absolute_error
print(f"MAE value : ", mean_absolute_error(y_test, y_pred))

from sklearn.metrics import mean_squared_error
print(f"MSE value : ", mean_squared_error(y_test, y_pred))

# %%
plt.scatter(x_train, y_train, color = "red")
plt.plot(x_train, lr.predict(x_train), color = "green")

# %% [markdown]
# #### Test-Train Splitting of Data for MAP

# %%
import random
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(pca_features, MAPdata, test_size=0.3, random_state=42,shuffle=True)

# %% [markdown]
# #### Training on Random Forest Regressor for MAP

# %%
from sklearn import ensemble
model = ensemble.RandomForestRegressor()
model = model.fit(X_train, y_train)
y_pred= model.predict(X_test)

# %% [markdown]
# #### R^2, MAE and MSE for MAP

# %%
from sklearn.metrics import r2_score
print(f"R^2 value : ", r2_score(y_test, y_pred))

from sklearn.metrics import mean_absolute_error
print(f"MAE value : ", mean_absolute_error(y_test, y_pred))

from sklearn.metrics import mean_squared_error
print(f"MSE value : ", mean_squared_error(y_test, y_pred))

# %% [markdown]
# #### For SBP

# %%
import random
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(selectedF, SBPdata, test_size=0.3, random_state=42,shuffle=True)

# %%
from sklearn import tree
model = tree.DecisionTreeRegressor()
model = model.fit(X_train, y_train)
y_pred= model.predict(X_test)

# %% [markdown]
# #### R^2, MAE and MSE for SBP

# %%
from sklearn.metrics import r2_score
print(f"R^2 value : ", r2_score(y_test, y_pred))

from sklearn.metrics import mean_absolute_error
print(f"MAE value : ", mean_absolute_error(y_test, y_pred))

from sklearn.metrics import mean_squared_error
print(f"MSE value : ", mean_squared_error(y_test, y_pred))

# %%
import random
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(selectedF, SBPdata, test_size=0.3, random_state=42,shuffle=True)

# %%
from sklearn import ensemble
model = ensemble.RandomForestRegressor()
model = model.fit(X_train, y_train)
y_pred= model.predict(X_test)

# %% [markdown]
# #### R^2, MAE and MSE for SBP

# %%
from sklearn.metrics import r2_score
print(f"R^2 value : ", r2_score(y_test, y_pred))

from sklearn.metrics import mean_absolute_error
print(f"MAE value : ", mean_absolute_error(y_test, y_pred))

from sklearn.metrics import mean_squared_error
print(f"MSE value : ", mean_squared_error(y_test, y_pred))

# %% [markdown]
# ### For DBP

# %%
import random
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(selectedF, DBPdata, test_size=0.3, random_state=42,shuffle=True)

# %%
from sklearn import tree
model = tree.DecisionTreeRegressor()
model = model.fit(X_train, y_train)
y_pred= model.predict(X_test)

# %% [markdown]
# #### R^2, MAE and MSE for DBP

# %%
from sklearn.metrics import r2_score
print(f"R^2 value : ", r2_score(y_test, y_pred))

from sklearn.metrics import mean_absolute_error
print(f"MAE value : ", mean_absolute_error(y_test, y_pred))

from sklearn.metrics import mean_squared_error
print(f"MSE value : ", mean_squared_error(y_test, y_pred))

# %%
import random
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(selectedF, DBPdata, test_size=0.3, random_state=42,shuffle=True)

# %%
from sklearn import ensemble
model = ensemble.RandomForestRegressor()
model = model.fit(X_train, y_train)
y_pred= model.predict(X_test)

# %% [markdown]
# #### R^2, MAE and MSE for DBP

# %%
from sklearn.metrics import r2_score
print(f"R^2 value : ", r2_score(y_test, y_pred))

from sklearn.metrics import mean_absolute_error
print(f"MAE value : ", mean_absolute_error(y_test, y_pred))

from sklearn.metrics import mean_squared_error
print(f"MSE value : ", mean_squared_error(y_test, y_pred))
